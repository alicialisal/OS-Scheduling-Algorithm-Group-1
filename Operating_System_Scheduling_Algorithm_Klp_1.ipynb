# %% [markdown]
# **Tugas Scheduling Algorithm**
#
# Kelompok 1 / IMT 23:
#
# Alicia Juanita Lisal (0806022310002)
#
# Andrey Hartawan Suwardi (0806022310021)
#
# Excel Marcello Parinussa (0806022310029)
#
# Felicia Wijaya (0806022310007)

# %%
import pandas as pd
from collections import deque
import copy

def load_processes_from_excel(file_path):
    df = pd.read_excel(file_path)
    processes = []
    for _, row in df.iterrows():
        processes.append({
            "pid": row['PID'],
            "arrival_time": row['arrival_time'],
            "burst_time": row['Burst_time']
        })
    return processes

# %% [markdown]
# Fungsi-fungsi Algoritma Scheduling

# %%
class ProcessScheduler:
    def __init__(self, processes):
        self.processes = processes
        self.timeline = []
        self.process_summary = []

    def create_timeline_df(self):
        df = pd.DataFrame(self.timeline)
        df.columns = ['Number', 'Second', 'PID']
        return df

    def create_summary_df(self):
        df = pd.DataFrame(self.process_summary)
        return df

    def calculate_averages(self):
        if not self.process_summary:
            return None

        total_waiting_time = sum(p['waiting_time'] for p in self.process_summary)
        total_turnaround_time = sum(p['complete_time'] - p['arrival_time'] for p in self.process_summary)
        n_processes = len(self.process_summary)

        return {
            'average_waiting_time': total_waiting_time / n_processes,
            'average_turnaround_time': total_turnaround_time / n_processes
        }

    def print_process_summary(self):
        for process in self.process_summary:
            print(f"process : {process['pid']}, arrival_time : {process['arrival_time']}, " +
                  f"burst_time : {process['burst_time']}, complete_time : {process['complete_time']}, " +
                  f"waiting_time : {process['waiting_time']}")

        averages = self.calculate_averages()
        if averages:
            print(f"\nAverages:")
            print(f"Average Waiting Time: {averages['average_waiting_time']:.2f}")
            print(f"Average Turnaround Time: {averages['average_turnaround_time']:.2f}")

    def fcfs(self):
        self.timeline = []
        self.process_summary = []
        sorted_processes = sorted(self.processes, key=lambda x: x["arrival_time"])
        current_time = 0
        counter = 0

        for process in sorted_processes:
            # Handle idle time
            while current_time < process["arrival_time"]:
                self.timeline.append([counter, current_time, "IDLE"])
                current_time += 1
                counter += 1

            waiting_time = current_time - process["arrival_time"]

            # Process execution
            remaining_time = process["burst_time"]
            while remaining_time > 0:
                self.timeline.append([counter, current_time, process["pid"]])
                current_time += 1
                remaining_time -= 1
                counter += 1

            # Add to process summary
            self.process_summary.append({
                "pid": process["pid"],
                "arrival_time": process["arrival_time"],
                "burst_time": process["burst_time"],
                "complete_time": current_time,
                "waiting_time": waiting_time
            })

        return self.timeline, self.process_summary

    def sjf_non_preemptive(self):
        self.timeline = []
        self.process_summary = []
        processes = sorted(self.processes, key=lambda x: x["arrival_time"])
        current_time = 0
        counter = 0
        ready_queue = []
        completed = []
        processes_copy = processes.copy()

        while len(completed) < len(processes):
            # Add arrived processes to ready queue
            while processes_copy and processes_copy[0]["arrival_time"] <= current_time:
                ready_queue.append(processes_copy.pop(0))

            if not ready_queue:
                self.timeline.append([counter, current_time, "IDLE"])
                current_time += 1
                counter += 1
                continue

            # Sort ready queue by burst time
            ready_queue.sort(key=lambda x: x["burst_time"])
            process = ready_queue.pop(0)
            waiting_time = current_time - process["arrival_time"]

            # Process execution
            remaining_time = process["burst_time"]
            while remaining_time > 0:
                self.timeline.append([counter, current_time, process["pid"]])
                current_time += 1
                remaining_time -= 1
                counter += 1

            # Add to process summary
            self.process_summary.append({
                "pid": process["pid"],
                "arrival_time": process["arrival_time"],
                "burst_time": process["burst_time"],
                "complete_time": current_time,
                "waiting_time": waiting_time
            })

            completed.append(process)

            # Add any new arrivals to ready queue
            while processes_copy and processes_copy[0]["arrival_time"] <= current_time:
                ready_queue.append(processes_copy.pop(0))

        return self.timeline, self.process_summary

    def sjf_preemptive(self):
        self.timeline = []
        self.process_summary = []
        processes = sorted(self.processes, key=lambda x: x["arrival_time"])
        current_time = 0
        counter = 0
        remaining_bt = {p["pid"]: p["burst_time"] for p in processes}
        completion_times = {}
        waiting_times = {p["pid"]: 0 for p in processes}
        last_run_time = {p["pid"]: 0 for p in processes}

        while any(remaining_bt.values()):
            # Find process with shortest remaining time
            shortest = None
            min_bt = float('inf')

            for process in processes:
                if process["arrival_time"] <= current_time and remaining_bt[process["pid"]] > 0:
                    if remaining_bt[process["pid"]] < min_bt:
                        min_bt = remaining_bt[process["pid"]]
                        shortest = process

            if shortest is None:
                self.timeline.append([counter, current_time, "IDLE"])
                current_time += 1
                counter += 1
                continue

            # Execute process for 1 time unit
            self.timeline.append([counter, current_time, shortest["pid"]])
            remaining_bt[shortest["pid"]] -= 1

            # Update waiting time
            for process in processes:
                if (process["pid"] != shortest["pid"] and
                    process["arrival_time"] <= current_time and
                    remaining_bt[process["pid"]] > 0):
                    waiting_times[process["pid"]] += 1

            current_time += 1
            counter += 1

            # Check if process is completed
            if remaining_bt[shortest["pid"]] == 0:
                completion_times[shortest["pid"]] = current_time

        # Create process summary
        for process in processes:
            self.process_summary.append({
                "pid": process["pid"],
                "arrival_time": process["arrival_time"],
                "burst_time": process["burst_time"],
                "complete_time": completion_times[process["pid"]],
                "waiting_time": waiting_times[process["pid"]]
            })

        return self.timeline, self.process_summary

    def round_robin(self, quantum=12):
        self.timeline = []
        self.process_summary = []
        processes = sorted(self.processes, key=lambda x: x["arrival_time"])
        current_time = 0
        counter = 0

        # Initialize remaining burst times and other tracking variables
        remaining_bt = {p["pid"]: p["burst_time"] for p in processes}
        completion_times = {}
        waiting_times = {p["pid"]: 0 for p in processes}
        ready_queue = deque()
        processes_copy = processes.copy()

        while any(remaining_bt.values()) or ready_queue:
            # Add newly arrived processes to ready queue
            while processes_copy and processes_copy[0]["arrival_time"] <= current_time:
                ready_queue.append(processes_copy.pop(0))

            if not ready_queue:
                self.timeline.append([counter, current_time, "IDLE"])
                current_time += 1
                counter += 1
                continue

            # Get next process from ready queue
            current_process = ready_queue.popleft()

            # Execute for quantum time or remaining burst time, whichever is smaller
            execution_time = min(quantum, remaining_bt[current_process["pid"]])

            # Update waiting times for other processes in ready queue
            for pid in remaining_bt:
                if (pid != current_process["pid"] and
                    remaining_bt[pid] > 0 and
                    any(p["pid"] == pid and p["arrival_time"] <= current_time for p in processes)):
                    waiting_times[pid] += execution_time

            # Execute process
            for _ in range(execution_time):
                self.timeline.append([counter, current_time, current_process["pid"]])
                current_time += 1
                counter += 1
                remaining_bt[current_process["pid"]] -= 1

                # Add any new arrivals to ready queue
                while processes_copy and processes_copy[0]["arrival_time"] <= current_time:
                    ready_queue.append(processes_copy.pop(0))

            # If process is not finished, add it back to ready queue
            if remaining_bt[current_process["pid"]] > 0:
                ready_queue.append(current_process)
            else:
                completion_times[current_process["pid"]] = current_time

        # Create process summary
        for process in processes:
            self.process_summary.append({
                "pid": process["pid"],
                "arrival_time": process["arrival_time"],
                "burst_time": process["burst_time"],
                "complete_time": completion_times[process["pid"]],
                "waiting_time": waiting_times[process["pid"]]
            })

        return self.timeline, self.process_summary

    def ljf_non_preemptive(self):
        self.timeline = []
        self.process_summary = []
        processes = sorted(self.processes, key=lambda x: x["arrival_time"])
        current_time = 0
        counter = 0
        ready_queue = []
        completed = []
        processes_copy = processes.copy()

        while len(completed) < len(processes):
            # Add arrived processes to ready queue
            while processes_copy and processes_copy[0]["arrival_time"] <= current_time:
                ready_queue.append(processes_copy.pop(0))

            if not ready_queue:
                self.timeline.append([counter, current_time, "IDLE"])
                current_time += 1
                counter += 1
                continue

            # Sort ready queue by burst time (descending for LJF)
            ready_queue.sort(key=lambda x: x["burst_time"], reverse=True)
            process = ready_queue.pop(0)
            waiting_time = current_time - process["arrival_time"]

            # Process execution
            remaining_time = process["burst_time"]
            while remaining_time > 0:
                self.timeline.append([counter, current_time, process["pid"]])
                current_time += 1
                remaining_time -= 1
                counter += 1

            # Add to process summary
            self.process_summary.append({
                "pid": process["pid"],
                "arrival_time": process["arrival_time"],
                "burst_time": process["burst_time"],
                "complete_time": current_time,
                "waiting_time": waiting_time
            })

            completed.append(process)

            # Add any new arrivals to ready queue
            while processes_copy and processes_copy[0]["arrival_time"] <= current_time:
                ready_queue.append(processes_copy.pop(0))

        return self.timeline, self.process_summary

    def save_results(self, output_file):
        # Create Excel writer object
        with pd.ExcelWriter(output_file) as writer:
            # Save timeline
            timeline_df = self.create_timeline_df()
            timeline_df.to_excel(writer, sheet_name='Timeline', index=False)

            # Save process summary
            summary_df = self.create_summary_df()
            summary_df.to_excel(writer, sheet_name='Process_Summary', index=False)

            # Save averages
            averages = self.calculate_averages()
            if averages:
                avg_df = pd.DataFrame([averages])
                avg_df.to_excel(writer, sheet_name='Averages', index=False)

# %%
def main():
    # Load processes from Excel
    input_file = 'processes.xlsx'
    processes = load_processes_from_excel(input_file)

    # Create scheduler instance
    scheduler = ProcessScheduler(processes)

    # Run different algorithms and save results
    algorithms = {
        'FCFS': scheduler.fcfs,
        'SJF_Non_Preemptive': scheduler.sjf_non_preemptive,
        'SJF_Preemptive': scheduler.sjf_preemptive,
        'Round_Robin': lambda: scheduler.round_robin(quantum=12),
        'LJF_Non_Preemptive': scheduler.ljf_non_preemptive
    }

    results_summary = []

    for algo_name, algo_func in algorithms.items():
        print(f"\n{algo_name} Results:")
        timeline, summary = algo_func()

        # Print process summary
        scheduler.print_process_summary()

        # Save to Excel
        output_file = f'{algo_name}_results.xlsx'
        scheduler.save_results(output_file)
        print(f"Results saved to {output_file}")

        # Store averages for comparison
        averages = scheduler.calculate_averages()
        if averages:
            averages['algorithm'] = algo_name
            results_summary.append(averages)

    # Create comparison DataFrame and save to Excel
    if results_summary:
        comparison_df = pd.DataFrame(results_summary)
        print("\nAlgorithm Comparison:")
        print(comparison_df)

if __name__ == "__main__":
    main()
# Out:
# FCFS Results:
# process : P51, arrival_time : 0, burst_time : 15, complete_time : 15, waiting_time : 0
# process : P66, arrival_time : 0, burst_time : 14, complete_time : 29, waiting_time : 15
# process : P98, arrival_time : 0, burst_time : 14, complete_time : 43, waiting_time : 29
# process : P39, arrival_time : 1, burst_time : 19, complete_time : 62, waiting_time : 42
# process : P40, arrival_time : 1, burst_time : 9, complete_time : 71, waiting_time : 61
# process : P90, arrival_time : 1, burst_time : 17, complete_time : 88, waiting_time : 70
# process : P23, arrival_time : 2, burst_time : 16, complete_time : 104, waiting_time : 86
# process : P55, arrival_time : 2, burst_time : 11, complete_time : 115, waiting_time : 102
# process : P8, arrival_time : 3, burst_time : 7, complete_time : 122, waiting_time : 112
# process : P21, arrival_time : 4, burst_time : 6, complete_time : 128, waiting_time : 118
# process : P44, arrival_time : 4, burst_time : 17, complete_time : 145, waiting_time : 124
# process : P11, arrival_time : 5, burst_time : 12, complete_time : 157, waiting_time : 140
# process : P87, arrival_time : 5, burst_time : 11, complete_time : 168, waiting_time : 152
# process : P88, arrival_time : 5, burst_time : 5, complete_time : 173, waiting_time : 163
# process : P30, arrival_time : 6, burst_time : 11, complete_time : 184, waiting_time : 167
# process : P60, arrival_time : 6, burst_time : 18, complete_time : 202, waiting_time : 178
# process : P84, arrival_time : 6, burst_time : 9, complete_time : 211, waiting_time : 196
# process : P17, arrival_time : 7, burst_time : 10, complete_time : 221, waiting_time : 204
# process : P48, arrival_time : 7, burst_time : 8, complete_time : 229, waiting_time : 214
# process : P3, arrival_time : 8, burst_time : 11, complete_time : 240, waiting_time : 221
# process : P34, arrival_time : 8, burst_time : 6, complete_time : 246, waiting_time : 232
# process : P71, arrival_time : 8, burst_time : 9, complete_time : 255, waiting_time : 238
# process : P92, arrival_time : 8, burst_time : 10, complete_time : 265, waiting_time : 247
# process : P12, arrival_time : 9, burst_time : 13, complete_time : 278, waiting_time : 256
# process : P47, arrival_time : 9, burst_time : 7, complete_time : 285, waiting_time : 269
# process : P72, arrival_time : 9, burst_time : 7, complete_time : 292, waiting_time : 276
# process : P82, arrival_time : 9, burst_time : 14, complete_time : 306, waiting_time : 283
# process : P5, arrival_time : 10, burst_time : 14, complete_time : 320, waiting_time : 296
# process : P16, arrival_time : 10, burst_time : 20, complete_time : 340, waiting_time : 310
# process : P43, arrival_time : 10, burst_time : 18, complete_time : 358, waiting_time : 330
# process : P54, arrival_time : 10, burst_time : 9, complete_time : 367, waiting_time : 348
# process : P63, arrival_time : 10, burst_time : 14, complete_time : 381, waiting_time : 357
# process : P85, arrival_time : 10, burst_time : 5, complete_time : 386, waiting_time : 371
# process : P2, arrival_time : 11, burst_time : 15, complete_time : 401, waiting_time : 375
# process : P10, arrival_time : 13, burst_time : 9, complete_time : 410, waiting_time : 388
# process : P28, arrival_time : 13, burst_time : 5, complete_time : 415, waiting_time : 397
# process : P61, arrival_time : 13, burst_time : 19, complete_time : 434, waiting_time : 402
# process : P96, arrival_time : 14, burst_time : 17, complete_time : 451, waiting_time : 420
# process : P29, arrival_time : 15, burst_time : 13, complete_time : 464, waiting_time : 436
# process : P57, arrival_time : 15, burst_time : 6, complete_time : 470, waiting_time : 449
# process : P75, arrival_time : 15, burst_time : 19, complete_time : 489, waiting_time : 455
# process : P80, arrival_time : 15, burst_time : 15, complete_time : 504, waiting_time : 474
# process : P52, arrival_time : 16, burst_time : 20, complete_time : 524, waiting_time : 488
# process : P99, arrival_time : 16, burst_time : 10, complete_time : 534, waiting_time : 508
# process : P49, arrival_time : 17, burst_time : 6, complete_time : 540, waiting_time : 517
# process : P4, arrival_time : 19, burst_time : 15, complete_time : 555, waiting_time : 521
# process : P14, arrival_time : 19, burst_time : 15, complete_time : 570, waiting_time : 536
# process : P50, arrival_time : 19, burst_time : 12, complete_time : 582, waiting_time : 551
# process : P70, arrival_time : 20, burst_time : 6, complete_time : 588, waiting_time : 562
# process : P76, arrival_time : 20, burst_time : 15, complete_time : 603, waiting_time : 568
# process : P91, arrival_time : 20, burst_time : 19, complete_time : 622, waiting_time : 583
# process : P86, arrival_time : 21, burst_time : 5, complete_time : 627, waiting_time : 601
# process : P20, arrival_time : 22, burst_time : 16, complete_time : 643, waiting_time : 605
# process : P45, arrival_time : 23, burst_time : 16, complete_time : 659, waiting_time : 620
# process : P74, arrival_time : 23, burst_time : 13, complete_time : 672, waiting_time : 636
# process : P18, arrival_time : 24, burst_time : 13, complete_time : 685, waiting_time : 648
# process : P59, arrival_time : 24, burst_time : 14, complete_time : 699, waiting_time : 661
# process : P77, arrival_time : 24, burst_time : 9, complete_time : 708, waiting_time : 675
# process : P68, arrival_time : 26, burst_time : 10, complete_time : 718, waiting_time : 682
# process : P94, arrival_time : 26, burst_time : 8, complete_time : 726, waiting_time : 692
# process : P9, arrival_time : 28, burst_time : 18, complete_time : 744, waiting_time : 698
# process : P93, arrival_time : 29, burst_time : 17, complete_time : 761, waiting_time : 715
# process : P46, arrival_time : 31, burst_time : 7, complete_time : 768, waiting_time : 730
# process : P69, arrival_time : 31, burst_time : 11, complete_time : 779, waiting_time : 737
# process : P97, arrival_time : 31, burst_time : 17, complete_time : 796, waiting_time : 748
# process : P13, arrival_time : 32, burst_time : 12, complete_time : 808, waiting_time : 764
# process : P15, arrival_time : 32, burst_time : 11, complete_time : 819, waiting_time : 776
# process : P56, arrival_time : 32, burst_time : 10, complete_time : 829, waiting_time : 787
# process : P37, arrival_time : 34, burst_time : 19, complete_time : 848, waiting_time : 795
# process : P53, arrival_time : 34, burst_time : 20, complete_time : 868, waiting_time : 814
# process : P81, arrival_time : 34, burst_time : 18, complete_time : 886, waiting_time : 834
# process : P26, arrival_time : 35, burst_time : 11, complete_time : 897, waiting_time : 851
# process : P19, arrival_time : 36, burst_time : 7, complete_time : 904, waiting_time : 861
# process : P79, arrival_time : 36, burst_time : 10, complete_time : 914, waiting_time : 868
# process : P100, arrival_time : 36, burst_time : 13, complete_time : 927, waiting_time : 878
# process : P33, arrival_time : 37, burst_time : 20, complete_time : 947, waiting_time : 890
# process : P62, arrival_time : 37, burst_time : 12, complete_time : 959, waiting_time : 910
# process : P25, arrival_time : 39, burst_time : 5, complete_time : 964, waiting_time : 920
# process : P78, arrival_time : 39, burst_time : 13, complete_time : 977, waiting_time : 925
# process : P1, arrival_time : 40, burst_time : 15, complete_time : 992, waiting_time : 937
# process : P24, arrival_time : 40, burst_time : 15, complete_time : 1007, waiting_time : 952
# process : P6, arrival_time : 41, burst_time : 12, complete_time : 1019, waiting_time : 966
# process : P41, arrival_time : 41, burst_time : 16, complete_time : 1035, waiting_time : 978
# process : P22, arrival_time : 42, burst_time : 20, complete_time : 1055, waiting_time : 993
# process : P36, arrival_time : 42, burst_time : 11, complete_time : 1066, waiting_time : 1013
# process : P65, arrival_time : 43, burst_time : 7, complete_time : 1073, waiting_time : 1023
# process : P35, arrival_time : 44, burst_time : 9, complete_time : 1082, waiting_time : 1029
# process : P31, arrival_time : 45, burst_time : 17, complete_time : 1099, waiting_time : 1037
# process : P7, arrival_time : 46, burst_time : 13, complete_time : 1112, waiting_time : 1053
# process : P64, arrival_time : 46, burst_time : 7, complete_time : 1119, waiting_time : 1066
# process : P67, arrival_time : 46, burst_time : 6, complete_time : 1125, waiting_time : 1073
# process : P32, arrival_time : 47, burst_time : 16, complete_time : 1141, waiting_time : 1078
# process : P27, arrival_time : 48, burst_time : 13, complete_time : 1154, waiting_time : 1093
# process : P89, arrival_time : 48, burst_time : 19, complete_time : 1173, waiting_time : 1106
# process : P38, arrival_time : 49, burst_time : 13, complete_time : 1186, waiting_time : 1124
# process : P42, arrival_time : 49, burst_time : 13, complete_time : 1199, waiting_time : 1137
# process : P58, arrival_time : 49, burst_time : 11, complete_time : 1210, waiting_time : 1150
# process : P73, arrival_time : 49, burst_time : 19, complete_time : 1229, waiting_time : 1161
# process : P95, arrival_time : 49, burst_time : 14, complete_time : 1243, waiting_time : 1180
# process : P83, arrival_time : 50, burst_time : 15, complete_time : 1258, waiting_time : 1193
#
# Averages:
# Average Waiting Time: 585.00
# Average Turnaround Time: 597.58
# Results saved to FCFS_results.xlsx
#
# SJF_Non_Preemptive Results:
# process : P66, arrival_time : 0, burst_time : 14, complete_time : 14, waiting_time : 0
# process : P88, arrival_time : 5, burst_time : 5, complete_time : 19, waiting_time : 9
# process : P85, arrival_time : 10, burst_time : 5, complete_time : 24, waiting_time : 9
# process : P28, arrival_time : 13, burst_time : 5, complete_time : 29, waiting_time : 11
# process : P86, arrival_time : 21, burst_time : 5, complete_time : 34, waiting_time : 8
# process : P21, arrival_time : 4, burst_time : 6, complete_time : 40, waiting_time : 30
# process : P25, arrival_time : 39, burst_time : 5, complete_time : 45, waiting_time : 1
# process : P34, arrival_time : 8, burst_time : 6, complete_time : 51, waiting_time : 37
# process : P57, arrival_time : 15, burst_time : 6, complete_time : 57, waiting_time : 36
# process : P49, arrival_time : 17, burst_time : 6, complete_time : 63, waiting_time : 40
# process : P70, arrival_time : 20, burst_time : 6, complete_time : 69, waiting_time : 43
# process : P67, arrival_time : 46, burst_time : 6, complete_time : 75, waiting_time : 23
# process : P8, arrival_time : 3, burst_time : 7, complete_time : 82, waiting_time : 72
# process : P47, arrival_time : 9, burst_time : 7, complete_time : 89, waiting_time : 73
# process : P72, arrival_time : 9, burst_time : 7, complete_time : 96, waiting_time : 80
# process : P46, arrival_time : 31, burst_time : 7, complete_time : 103, waiting_time : 65
# process : P19, arrival_time : 36, burst_time : 7, complete_time : 110, waiting_time : 67
# process : P65, arrival_time : 43, burst_time : 7, complete_time : 117, waiting_time : 67
# process : P64, arrival_time : 46, burst_time : 7, complete_time : 124, waiting_time : 71
# process : P48, arrival_time : 7, burst_time : 8, complete_time : 132, waiting_time : 117
# process : P94, arrival_time : 26, burst_time : 8, complete_time : 140, waiting_time : 106
# process : P40, arrival_time : 1, burst_time : 9, complete_time : 149, waiting_time : 139
# process : P84, arrival_time : 6, burst_time : 9, complete_time : 158, waiting_time : 143
# process : P71, arrival_time : 8, burst_time : 9, complete_time : 167, waiting_time : 150
# process : P54, arrival_time : 10, burst_time : 9, complete_time : 176, waiting_time : 157
# process : P10, arrival_time : 13, burst_time : 9, complete_time : 185, waiting_time : 163
# process : P77, arrival_time : 24, burst_time : 9, complete_time : 194, waiting_time : 161
# process : P35, arrival_time : 44, burst_time : 9, complete_time : 203, waiting_time : 150
# process : P17, arrival_time : 7, burst_time : 10, complete_time : 213, waiting_time : 196
# process : P92, arrival_time : 8, burst_time : 10, complete_time : 223, waiting_time : 205
# process : P99, arrival_time : 16, burst_time : 10, complete_time : 233, waiting_time : 207
# process : P68, arrival_time : 26, burst_time : 10, complete_time : 243, waiting_time : 207
# process : P56, arrival_time : 32, burst_time : 10, complete_time : 253, waiting_time : 211
# process : P79, arrival_time : 36, burst_time : 10, complete_time : 263, waiting_time : 217
# process : P55, arrival_time : 2, burst_time : 11, complete_time : 274, waiting_time : 261
# process : P87, arrival_time : 5, burst_time : 11, complete_time : 285, waiting_time : 269
# process : P30, arrival_time : 6, burst_time : 11, complete_time : 296, waiting_time : 279
# process : P3, arrival_time : 8, burst_time : 11, complete_time : 307, waiting_time : 288
# process : P69, arrival_time : 31, burst_time : 11, complete_time : 318, waiting_time : 276
# process : P15, arrival_time : 32, burst_time : 11, complete_time : 329, waiting_time : 286
# process : P26, arrival_time : 35, burst_time : 11, complete_time : 340, waiting_time : 294
# process : P36, arrival_time : 42, burst_time : 11, complete_time : 351, waiting_time : 298
# process : P58, arrival_time : 49, burst_time : 11, complete_time : 362, waiting_time : 302
# process : P11, arrival_time : 5, burst_time : 12, complete_time : 374, waiting_time : 357
# process : P50, arrival_time : 19, burst_time : 12, complete_time : 386, waiting_time : 355
# process : P13, arrival_time : 32, burst_time : 12, complete_time : 398, waiting_time : 354
# process : P62, arrival_time : 37, burst_time : 12, complete_time : 410, waiting_time : 361
# process : P6, arrival_time : 41, burst_time : 12, complete_time : 422, waiting_time : 369
# process : P12, arrival_time : 9, burst_time : 13, complete_time : 435, waiting_time : 413
# process : P29, arrival_time : 15, burst_time : 13, complete_time : 448, waiting_time : 420
# process : P74, arrival_time : 23, burst_time : 13, complete_time : 461, waiting_time : 425
# process : P18, arrival_time : 24, burst_time : 13, complete_time : 474, waiting_time : 437
# process : P100, arrival_time : 36, burst_time : 13, complete_time : 487, waiting_time : 438
# process : P78, arrival_time : 39, burst_time : 13, complete_time : 500, waiting_time : 448
# process : P7, arrival_time : 46, burst_time : 13, complete_time : 513, waiting_time : 454
# process : P27, arrival_time : 48, burst_time : 13, complete_time : 526, waiting_time : 465
# process : P38, arrival_time : 49, burst_time : 13, complete_time : 539, waiting_time : 477
# process : P42, arrival_time : 49, burst_time : 13, complete_time : 552, waiting_time : 490
# process : P98, arrival_time : 0, burst_time : 14, complete_time : 566, waiting_time : 552
# process : P82, arrival_time : 9, burst_time : 14, complete_time : 580, waiting_time : 557
# process : P5, arrival_time : 10, burst_time : 14, complete_time : 594, waiting_time : 570
# process : P63, arrival_time : 10, burst_time : 14, complete_time : 608, waiting_time : 584
# process : P59, arrival_time : 24, burst_time : 14, complete_time : 622, waiting_time : 584
# process : P95, arrival_time : 49, burst_time : 14, complete_time : 636, waiting_time : 573
# process : P51, arrival_time : 0, burst_time : 15, complete_time : 651, waiting_time : 636
# process : P2, arrival_time : 11, burst_time : 15, complete_time : 666, waiting_time : 640
# process : P80, arrival_time : 15, burst_time : 15, complete_time : 681, waiting_time : 651
# process : P4, arrival_time : 19, burst_time : 15, complete_time : 696, waiting_time : 662
# process : P14, arrival_time : 19, burst_time : 15, complete_time : 711, waiting_time : 677
# process : P76, arrival_time : 20, burst_time : 15, complete_time : 726, waiting_time : 691
# process : P1, arrival_time : 40, burst_time : 15, complete_time : 741, waiting_time : 686
# process : P24, arrival_time : 40, burst_time : 15, complete_time : 756, waiting_time : 701
# process : P83, arrival_time : 50, burst_time : 15, complete_time : 771, waiting_time : 706
# process : P23, arrival_time : 2, burst_time : 16, complete_time : 787, waiting_time : 769
# process : P20, arrival_time : 22, burst_time : 16, complete_time : 803, waiting_time : 765
# process : P45, arrival_time : 23, burst_time : 16, complete_time : 819, waiting_time : 780
# process : P41, arrival_time : 41, burst_time : 16, complete_time : 835, waiting_time : 778
# process : P32, arrival_time : 47, burst_time : 16, complete_time : 851, waiting_time : 788
# process : P90, arrival_time : 1, burst_time : 17, complete_time : 868, waiting_time : 850
# process : P44, arrival_time : 4, burst_time : 17, complete_time : 885, waiting_time : 864
# process : P96, arrival_time : 14, burst_time : 17, complete_time : 902, waiting_time : 871
# process : P93, arrival_time : 29, burst_time : 17, complete_time : 919, waiting_time : 873
# process : P97, arrival_time : 31, burst_time : 17, complete_time : 936, waiting_time : 888
# process : P31, arrival_time : 45, burst_time : 17, complete_time : 953, waiting_time : 891
# process : P60, arrival_time : 6, burst_time : 18, complete_time : 971, waiting_time : 947
# process : P43, arrival_time : 10, burst_time : 18, complete_time : 989, waiting_time : 961
# process : P9, arrival_time : 28, burst_time : 18, complete_time : 1007, waiting_time : 961
# process : P81, arrival_time : 34, burst_time : 18, complete_time : 1025, waiting_time : 973
# process : P39, arrival_time : 1, burst_time : 19, complete_time : 1044, waiting_time : 1024
# process : P61, arrival_time : 13, burst_time : 19, complete_time : 1063, waiting_time : 1031
# process : P75, arrival_time : 15, burst_time : 19, complete_time : 1082, waiting_time : 1048
# process : P91, arrival_time : 20, burst_time : 19, complete_time : 1101, waiting_time : 1062
# process : P37, arrival_time : 34, burst_time : 19, complete_time : 1120, waiting_time : 1067
# process : P89, arrival_time : 48, burst_time : 19, complete_time : 1139, waiting_time : 1072
# process : P73, arrival_time : 49, burst_time : 19, complete_time : 1158, waiting_time : 1090
# process : P16, arrival_time : 10, burst_time : 20, complete_time : 1178, waiting_time : 1148
# process : P52, arrival_time : 16, burst_time : 20, complete_time : 1198, waiting_time : 1162
# process : P53, arrival_time : 34, burst_time : 20, complete_time : 1218, waiting_time : 1164
# process : P33, arrival_time : 37, burst_time : 20, complete_time : 1238, waiting_time : 1181
# process : P22, arrival_time : 42, burst_time : 20, complete_time : 1258, waiting_time : 1196
#
# Averages:
# Average Waiting Time: 477.61
# Average Turnaround Time: 490.19
# Results saved to SJF_Non_Preemptive_results.xlsx
#
# SJF_Preemptive Results:
# process : P51, arrival_time : 0, burst_time : 15, complete_time : 651, waiting_time : 636
# process : P66, arrival_time : 0, burst_time : 14, complete_time : 422, waiting_time : 408
# process : P98, arrival_time : 0, burst_time : 14, complete_time : 566, waiting_time : 552
# process : P39, arrival_time : 1, burst_time : 19, complete_time : 1044, waiting_time : 1024
# process : P40, arrival_time : 1, burst_time : 9, complete_time : 10, waiting_time : 0
# process : P90, arrival_time : 1, burst_time : 17, complete_time : 868, waiting_time : 850
# process : P23, arrival_time : 2, burst_time : 16, complete_time : 787, waiting_time : 769
# process : P55, arrival_time : 2, burst_time : 11, complete_time : 261, waiting_time : 248
# process : P8, arrival_time : 3, burst_time : 7, complete_time : 78, waiting_time : 68
# process : P21, arrival_time : 4, burst_time : 6, complete_time : 36, waiting_time : 26
# process : P44, arrival_time : 4, burst_time : 17, complete_time : 885, waiting_time : 864
# process : P11, arrival_time : 5, burst_time : 12, complete_time : 361, waiting_time : 344
# process : P87, arrival_time : 5, burst_time : 11, complete_time : 272, waiting_time : 256
# process : P88, arrival_time : 5, burst_time : 5, complete_time : 15, waiting_time : 5
# process : P30, arrival_time : 6, burst_time : 11, complete_time : 283, waiting_time : 266
# process : P60, arrival_time : 6, burst_time : 18, complete_time : 971, waiting_time : 947
# process : P84, arrival_time : 6, burst_time : 9, complete_time : 145, waiting_time : 130
# process : P17, arrival_time : 7, burst_time : 10, complete_time : 200, waiting_time : 183
# process : P48, arrival_time : 7, burst_time : 8, complete_time : 128, waiting_time : 113
# process : P3, arrival_time : 8, burst_time : 11, complete_time : 294, waiting_time : 275
# process : P34, arrival_time : 8, burst_time : 6, complete_time : 42, waiting_time : 28
# process : P71, arrival_time : 8, burst_time : 9, complete_time : 154, waiting_time : 137
# process : P92, arrival_time : 8, burst_time : 10, complete_time : 210, waiting_time : 192
# process : P12, arrival_time : 9, burst_time : 13, complete_time : 435, waiting_time : 413
# process : P47, arrival_time : 9, burst_time : 7, complete_time : 85, waiting_time : 69
# process : P72, arrival_time : 9, burst_time : 7, complete_time : 92, waiting_time : 76
# process : P82, arrival_time : 9, burst_time : 14, complete_time : 580, waiting_time : 557
# process : P5, arrival_time : 10, burst_time : 14, complete_time : 594, waiting_time : 570
# process : P16, arrival_time : 10, burst_time : 20, complete_time : 1178, waiting_time : 1148
# process : P43, arrival_time : 10, burst_time : 18, complete_time : 989, waiting_time : 961
# process : P54, arrival_time : 10, burst_time : 9, complete_time : 163, waiting_time : 144
# process : P63, arrival_time : 10, burst_time : 14, complete_time : 608, waiting_time : 584
# process : P85, arrival_time : 10, burst_time : 5, complete_time : 20, waiting_time : 5
# process : P2, arrival_time : 11, burst_time : 15, complete_time : 666, waiting_time : 640
# process : P10, arrival_time : 13, burst_time : 9, complete_time : 172, waiting_time : 150
# process : P28, arrival_time : 13, burst_time : 5, complete_time : 25, waiting_time : 7
# process : P61, arrival_time : 13, burst_time : 19, complete_time : 1063, waiting_time : 1031
# process : P96, arrival_time : 14, burst_time : 17, complete_time : 902, waiting_time : 871
# process : P29, arrival_time : 15, burst_time : 13, complete_time : 448, waiting_time : 420
# process : P57, arrival_time : 15, burst_time : 6, complete_time : 53, waiting_time : 32
# process : P75, arrival_time : 15, burst_time : 19, complete_time : 1082, waiting_time : 1048
# process : P80, arrival_time : 15, burst_time : 15, complete_time : 681, waiting_time : 651
# process : P52, arrival_time : 16, burst_time : 20, complete_time : 1198, waiting_time : 1162
# process : P99, arrival_time : 16, burst_time : 10, complete_time : 220, waiting_time : 194
# process : P49, arrival_time : 17, burst_time : 6, complete_time : 59, waiting_time : 36
# process : P4, arrival_time : 19, burst_time : 15, complete_time : 696, waiting_time : 662
# process : P14, arrival_time : 19, burst_time : 15, complete_time : 711, waiting_time : 677
# process : P50, arrival_time : 19, burst_time : 12, complete_time : 373, waiting_time : 342
# process : P70, arrival_time : 20, burst_time : 6, complete_time : 65, waiting_time : 39
# process : P76, arrival_time : 20, burst_time : 15, complete_time : 726, waiting_time : 691
# process : P91, arrival_time : 20, burst_time : 19, complete_time : 1101, waiting_time : 1062
# process : P86, arrival_time : 21, burst_time : 5, complete_time : 30, waiting_time : 4
# process : P20, arrival_time : 22, burst_time : 16, complete_time : 803, waiting_time : 765
# process : P45, arrival_time : 23, burst_time : 16, complete_time : 819, waiting_time : 780
# process : P74, arrival_time : 23, burst_time : 13, complete_time : 461, waiting_time : 425
# process : P18, arrival_time : 24, burst_time : 13, complete_time : 474, waiting_time : 437
# process : P59, arrival_time : 24, burst_time : 14, complete_time : 622, waiting_time : 584
# process : P77, arrival_time : 24, burst_time : 9, complete_time : 181, waiting_time : 148
# process : P68, arrival_time : 26, burst_time : 10, complete_time : 230, waiting_time : 194
# process : P94, arrival_time : 26, burst_time : 8, complete_time : 136, waiting_time : 102
# process : P9, arrival_time : 28, burst_time : 18, complete_time : 1007, waiting_time : 961
# process : P93, arrival_time : 29, burst_time : 17, complete_time : 919, waiting_time : 873
# process : P46, arrival_time : 31, burst_time : 7, complete_time : 99, waiting_time : 61
# process : P69, arrival_time : 31, burst_time : 11, complete_time : 305, waiting_time : 263
# process : P97, arrival_time : 31, burst_time : 17, complete_time : 936, waiting_time : 888
# process : P13, arrival_time : 32, burst_time : 12, complete_time : 385, waiting_time : 341
# process : P15, arrival_time : 32, burst_time : 11, complete_time : 316, waiting_time : 273
# process : P56, arrival_time : 32, burst_time : 10, complete_time : 240, waiting_time : 198
# process : P37, arrival_time : 34, burst_time : 19, complete_time : 1120, waiting_time : 1067
# process : P53, arrival_time : 34, burst_time : 20, complete_time : 1218, waiting_time : 1164
# process : P81, arrival_time : 34, burst_time : 18, complete_time : 1025, waiting_time : 973
# process : P26, arrival_time : 35, burst_time : 11, complete_time : 327, waiting_time : 281
# process : P19, arrival_time : 36, burst_time : 7, complete_time : 106, waiting_time : 63
# process : P79, arrival_time : 36, burst_time : 10, complete_time : 250, waiting_time : 204
# process : P100, arrival_time : 36, burst_time : 13, complete_time : 487, waiting_time : 438
# process : P33, arrival_time : 37, burst_time : 20, complete_time : 1238, waiting_time : 1181
# process : P62, arrival_time : 37, burst_time : 12, complete_time : 397, waiting_time : 348
# process : P25, arrival_time : 39, burst_time : 5, complete_time : 47, waiting_time : 3
# process : P78, arrival_time : 39, burst_time : 13, complete_time : 500, waiting_time : 448
# process : P1, arrival_time : 40, burst_time : 15, complete_time : 741, waiting_time : 686
# process : P24, arrival_time : 40, burst_time : 15, complete_time : 756, waiting_time : 701
# process : P6, arrival_time : 41, burst_time : 12, complete_time : 409, waiting_time : 356
# process : P41, arrival_time : 41, burst_time : 16, complete_time : 835, waiting_time : 778
# process : P22, arrival_time : 42, burst_time : 20, complete_time : 1258, waiting_time : 1196
# process : P36, arrival_time : 42, burst_time : 11, complete_time : 338, waiting_time : 285
# process : P65, arrival_time : 43, burst_time : 7, complete_time : 113, waiting_time : 63
# process : P35, arrival_time : 44, burst_time : 9, complete_time : 190, waiting_time : 137
# process : P31, arrival_time : 45, burst_time : 17, complete_time : 953, waiting_time : 891
# process : P7, arrival_time : 46, burst_time : 13, complete_time : 513, waiting_time : 454
# process : P64, arrival_time : 46, burst_time : 7, complete_time : 120, waiting_time : 67
# process : P67, arrival_time : 46, burst_time : 6, complete_time : 71, waiting_time : 19
# process : P32, arrival_time : 47, burst_time : 16, complete_time : 851, waiting_time : 788
# process : P27, arrival_time : 48, burst_time : 13, complete_time : 526, waiting_time : 465
# process : P89, arrival_time : 48, burst_time : 19, complete_time : 1139, waiting_time : 1072
# process : P38, arrival_time : 49, burst_time : 13, complete_time : 539, waiting_time : 477
# process : P42, arrival_time : 49, burst_time : 13, complete_time : 552, waiting_time : 490
# process : P58, arrival_time : 49, burst_time : 11, complete_time : 349, waiting_time : 289
# process : P73, arrival_time : 49, burst_time : 19, complete_time : 1158, waiting_time : 1090
# process : P95, arrival_time : 49, burst_time : 14, complete_time : 636, waiting_time : 573
# process : P83, arrival_time : 50, burst_time : 15, complete_time : 771, waiting_time : 706
#
# Averages:
# Average Waiting Time: 476.13
# Average Turnaround Time: 488.71
# Results saved to SJF_Preemptive_results.xlsx
#
# Round_Robin Results:
# process : P51, arrival_time : 0, burst_time : 15, complete_time : 346, waiting_time : 331
# process : P66, arrival_time : 0, burst_time : 14, complete_time : 596, waiting_time : 582
# process : P98, arrival_time : 0, burst_time : 14, complete_time : 779, waiting_time : 765
# process : P39, arrival_time : 1, burst_time : 19, complete_time : 987, waiting_time : 956
# process : P40, arrival_time : 1, burst_time : 9, complete_time : 57, waiting_time : 36
# process : P90, arrival_time : 1, burst_time : 17, complete_time : 1063, waiting_time : 1034
# process : P23, arrival_time : 2, burst_time : 16, complete_time : 1067, waiting_time : 1039
# process : P55, arrival_time : 2, burst_time : 11, complete_time : 92, waiting_time : 69
# process : P8, arrival_time : 3, burst_time : 7, complete_time : 99, waiting_time : 80
# process : P21, arrival_time : 4, burst_time : 6, complete_time : 105, waiting_time : 87
# process : P44, arrival_time : 4, burst_time : 17, complete_time : 1072, waiting_time : 1043
# process : P11, arrival_time : 5, burst_time : 12, complete_time : 129, waiting_time : 105
# process : P87, arrival_time : 5, burst_time : 11, complete_time : 140, waiting_time : 117
# process : P88, arrival_time : 5, burst_time : 5, complete_time : 145, waiting_time : 128
# process : P30, arrival_time : 6, burst_time : 11, complete_time : 156, waiting_time : 133
# process : P60, arrival_time : 6, burst_time : 18, complete_time : 1078, waiting_time : 1048
# process : P84, arrival_time : 6, burst_time : 9, complete_time : 177, waiting_time : 156
# process : P17, arrival_time : 7, burst_time : 10, complete_time : 187, waiting_time : 165
# process : P48, arrival_time : 7, burst_time : 8, complete_time : 195, waiting_time : 175
# process : P3, arrival_time : 8, burst_time : 11, complete_time : 206, waiting_time : 183
# process : P34, arrival_time : 8, burst_time : 6, complete_time : 212, waiting_time : 194
# process : P71, arrival_time : 8, burst_time : 9, complete_time : 221, waiting_time : 200
# process : P92, arrival_time : 8, burst_time : 10, complete_time : 231, waiting_time : 209
# process : P12, arrival_time : 9, burst_time : 13, complete_time : 1079, waiting_time : 1054
# process : P47, arrival_time : 9, burst_time : 7, complete_time : 250, waiting_time : 231
# process : P72, arrival_time : 9, burst_time : 7, complete_time : 257, waiting_time : 238
# process : P82, arrival_time : 9, burst_time : 14, complete_time : 1081, waiting_time : 1055
# process : P5, arrival_time : 10, burst_time : 14, complete_time : 1083, waiting_time : 1057
# process : P16, arrival_time : 10, burst_time : 20, complete_time : 1091, waiting_time : 1059
# process : P43, arrival_time : 10, burst_time : 18, complete_time : 1097, waiting_time : 1067
# process : P54, arrival_time : 10, burst_time : 9, complete_time : 314, waiting_time : 293
# process : P63, arrival_time : 10, burst_time : 14, complete_time : 1099, waiting_time : 1073
# process : P85, arrival_time : 10, burst_time : 5, complete_time : 331, waiting_time : 314
# process : P2, arrival_time : 11, burst_time : 15, complete_time : 1102, waiting_time : 1075
# process : P10, arrival_time : 13, burst_time : 9, complete_time : 355, waiting_time : 322
# process : P28, arrival_time : 13, burst_time : 5, complete_time : 360, waiting_time : 331
# process : P61, arrival_time : 13, burst_time : 19, complete_time : 1109, waiting_time : 1066
# process : P96, arrival_time : 14, burst_time : 17, complete_time : 1114, waiting_time : 1073
# process : P29, arrival_time : 15, burst_time : 13, complete_time : 1115, waiting_time : 1078
# process : P57, arrival_time : 15, burst_time : 6, complete_time : 402, waiting_time : 372
# process : P75, arrival_time : 15, burst_time : 19, complete_time : 1122, waiting_time : 1079
# process : P80, arrival_time : 15, burst_time : 15, complete_time : 1125, waiting_time : 1086
# process : P52, arrival_time : 16, burst_time : 20, complete_time : 1133, waiting_time : 1089
# process : P99, arrival_time : 16, burst_time : 10, complete_time : 448, waiting_time : 414
# process : P49, arrival_time : 17, burst_time : 6, complete_time : 454, waiting_time : 424
# process : P4, arrival_time : 19, burst_time : 15, complete_time : 1136, waiting_time : 1097
# process : P14, arrival_time : 19, burst_time : 15, complete_time : 1139, waiting_time : 1100
# process : P50, arrival_time : 19, burst_time : 12, complete_time : 490, waiting_time : 454
# process : P70, arrival_time : 20, burst_time : 6, complete_time : 496, waiting_time : 466
# process : P76, arrival_time : 20, burst_time : 15, complete_time : 1142, waiting_time : 1103
# process : P91, arrival_time : 20, burst_time : 19, complete_time : 1149, waiting_time : 1106
# process : P86, arrival_time : 21, burst_time : 5, complete_time : 525, waiting_time : 496
# process : P20, arrival_time : 22, burst_time : 16, complete_time : 1153, waiting_time : 1113
# process : P45, arrival_time : 23, burst_time : 16, complete_time : 1157, waiting_time : 1117
# process : P74, arrival_time : 23, burst_time : 13, complete_time : 1158, waiting_time : 1121
# process : P18, arrival_time : 24, burst_time : 13, complete_time : 1159, waiting_time : 1122
# process : P59, arrival_time : 24, burst_time : 14, complete_time : 1161, waiting_time : 1123
# process : P77, arrival_time : 24, burst_time : 9, complete_time : 594, waiting_time : 561
# process : P68, arrival_time : 26, burst_time : 10, complete_time : 606, waiting_time : 560
# process : P94, arrival_time : 26, burst_time : 8, complete_time : 614, waiting_time : 570
# process : P9, arrival_time : 28, burst_time : 18, complete_time : 1167, waiting_time : 1113
# process : P93, arrival_time : 29, burst_time : 17, complete_time : 1172, waiting_time : 1119
# process : P46, arrival_time : 31, burst_time : 7, complete_time : 645, waiting_time : 602
# process : P69, arrival_time : 31, burst_time : 11, complete_time : 656, waiting_time : 609
# process : P97, arrival_time : 31, burst_time : 17, complete_time : 1177, waiting_time : 1124
# process : P13, arrival_time : 32, burst_time : 12, complete_time : 680, waiting_time : 632
# process : P15, arrival_time : 32, burst_time : 11, complete_time : 691, waiting_time : 644
# process : P56, arrival_time : 32, burst_time : 10, complete_time : 701, waiting_time : 655
# process : P37, arrival_time : 34, burst_time : 19, complete_time : 1184, waiting_time : 1129
# process : P53, arrival_time : 34, burst_time : 20, complete_time : 1192, waiting_time : 1136
# process : P81, arrival_time : 34, burst_time : 18, complete_time : 1198, waiting_time : 1144
# process : P26, arrival_time : 35, burst_time : 11, complete_time : 748, waiting_time : 701
# process : P19, arrival_time : 36, burst_time : 7, complete_time : 755, waiting_time : 712
# process : P79, arrival_time : 36, burst_time : 10, complete_time : 765, waiting_time : 719
# process : P100, arrival_time : 36, burst_time : 13, complete_time : 1199, waiting_time : 1150
# process : P33, arrival_time : 37, burst_time : 20, complete_time : 1207, waiting_time : 1139
# process : P62, arrival_time : 37, burst_time : 12, complete_time : 803, waiting_time : 743
# process : P25, arrival_time : 39, burst_time : 5, complete_time : 808, waiting_time : 755
# process : P78, arrival_time : 39, burst_time : 13, complete_time : 1208, waiting_time : 1147
# process : P1, arrival_time : 40, burst_time : 15, complete_time : 1211, waiting_time : 1148
# process : P24, arrival_time : 40, burst_time : 15, complete_time : 1214, waiting_time : 1151
# process : P6, arrival_time : 41, burst_time : 12, complete_time : 856, waiting_time : 796
# process : P41, arrival_time : 41, burst_time : 16, complete_time : 1218, waiting_time : 1154
# process : P22, arrival_time : 42, burst_time : 20, complete_time : 1226, waiting_time : 1158
# process : P36, arrival_time : 42, burst_time : 11, complete_time : 891, waiting_time : 832
# process : P65, arrival_time : 43, burst_time : 7, complete_time : 898, waiting_time : 843
# process : P35, arrival_time : 44, burst_time : 9, complete_time : 907, waiting_time : 850
# process : P31, arrival_time : 45, burst_time : 17, complete_time : 1231, waiting_time : 1166
# process : P7, arrival_time : 46, burst_time : 13, complete_time : 1232, waiting_time : 1171
# process : P64, arrival_time : 46, burst_time : 7, complete_time : 938, waiting_time : 883
# process : P67, arrival_time : 46, burst_time : 6, complete_time : 944, waiting_time : 890
# process : P32, arrival_time : 47, burst_time : 16, complete_time : 1236, waiting_time : 1172
# process : P27, arrival_time : 48, burst_time : 13, complete_time : 1237, waiting_time : 1176
# process : P89, arrival_time : 48, burst_time : 19, complete_time : 1244, waiting_time : 1177
# process : P38, arrival_time : 49, burst_time : 13, complete_time : 1245, waiting_time : 1175
# process : P42, arrival_time : 49, burst_time : 13, complete_time : 1246, waiting_time : 1176
# process : P58, arrival_time : 49, burst_time : 11, complete_time : 1022, waiting_time : 954
# process : P73, arrival_time : 49, burst_time : 19, complete_time : 1253, waiting_time : 1177
# process : P95, arrival_time : 49, burst_time : 14, complete_time : 1255, waiting_time : 1184
# process : P83, arrival_time : 50, burst_time : 15, complete_time : 1258, waiting_time : 1186
#
# Averages:
# Average Waiting Time: 781.86
# Average Turnaround Time: 799.65
# Results saved to Round_Robin_results.xlsx
#
# LJF_Non_Preemptive Results:
# process : P51, arrival_time : 0, burst_time : 15, complete_time : 15, waiting_time : 0
# process : P16, arrival_time : 10, burst_time : 20, complete_time : 35, waiting_time : 5
# process : P52, arrival_time : 16, burst_time : 20, complete_time : 55, waiting_time : 19
# process : P53, arrival_time : 34, burst_time : 20, complete_time : 75, waiting_time : 21
# process : P33, arrival_time : 37, burst_time : 20, complete_time : 95, waiting_time : 38
# process : P22, arrival_time : 42, burst_time : 20, complete_time : 115, waiting_time : 53
# process : P39, arrival_time : 1, burst_time : 19, complete_time : 134, waiting_time : 114
# process : P61, arrival_time : 13, burst_time : 19, complete_time : 153, waiting_time : 121
# process : P75, arrival_time : 15, burst_time : 19, complete_time : 172, waiting_time : 138
# process : P91, arrival_time : 20, burst_time : 19, complete_time : 191, waiting_time : 152
# process : P37, arrival_time : 34, burst_time : 19, complete_time : 210, waiting_time : 157
# process : P89, arrival_time : 48, burst_time : 19, complete_time : 229, waiting_time : 162
# process : P73, arrival_time : 49, burst_time : 19, complete_time : 248, waiting_time : 180
# process : P60, arrival_time : 6, burst_time : 18, complete_time : 266, waiting_time : 242
# process : P43, arrival_time : 10, burst_time : 18, complete_time : 284, waiting_time : 256
# process : P9, arrival_time : 28, burst_time : 18, complete_time : 302, waiting_time : 256
# process : P81, arrival_time : 34, burst_time : 18, complete_time : 320, waiting_time : 268
# process : P90, arrival_time : 1, burst_time : 17, complete_time : 337, waiting_time : 319
# process : P44, arrival_time : 4, burst_time : 17, complete_time : 354, waiting_time : 333
# process : P96, arrival_time : 14, burst_time : 17, complete_time : 371, waiting_time : 340
# process : P93, arrival_time : 29, burst_time : 17, complete_time : 388, waiting_time : 342
# process : P97, arrival_time : 31, burst_time : 17, complete_time : 405, waiting_time : 357
# process : P31, arrival_time : 45, burst_time : 17, complete_time : 422, waiting_time : 360
# process : P23, arrival_time : 2, burst_time : 16, complete_time : 438, waiting_time : 420
# process : P20, arrival_time : 22, burst_time : 16, complete_time : 454, waiting_time : 416
# process : P45, arrival_time : 23, burst_time : 16, complete_time : 470, waiting_time : 431
# process : P41, arrival_time : 41, burst_time : 16, complete_time : 486, waiting_time : 429
# process : P32, arrival_time : 47, burst_time : 16, complete_time : 502, waiting_time : 439
# process : P2, arrival_time : 11, burst_time : 15, complete_time : 517, waiting_time : 491
# process : P80, arrival_time : 15, burst_time : 15, complete_time : 532, waiting_time : 502
# process : P4, arrival_time : 19, burst_time : 15, complete_time : 547, waiting_time : 513
# process : P14, arrival_time : 19, burst_time : 15, complete_time : 562, waiting_time : 528
# process : P76, arrival_time : 20, burst_time : 15, complete_time : 577, waiting_time : 542
# process : P1, arrival_time : 40, burst_time : 15, complete_time : 592, waiting_time : 537
# process : P24, arrival_time : 40, burst_time : 15, complete_time : 607, waiting_time : 552
# process : P83, arrival_time : 50, burst_time : 15, complete_time : 622, waiting_time : 557
# process : P66, arrival_time : 0, burst_time : 14, complete_time : 636, waiting_time : 622
# process : P98, arrival_time : 0, burst_time : 14, complete_time : 650, waiting_time : 636
# process : P82, arrival_time : 9, burst_time : 14, complete_time : 664, waiting_time : 641
# process : P5, arrival_time : 10, burst_time : 14, complete_time : 678, waiting_time : 654
# process : P63, arrival_time : 10, burst_time : 14, complete_time : 692, waiting_time : 668
# process : P59, arrival_time : 24, burst_time : 14, complete_time : 706, waiting_time : 668
# process : P95, arrival_time : 49, burst_time : 14, complete_time : 720, waiting_time : 657
# process : P12, arrival_time : 9, burst_time : 13, complete_time : 733, waiting_time : 711
# process : P29, arrival_time : 15, burst_time : 13, complete_time : 746, waiting_time : 718
# process : P74, arrival_time : 23, burst_time : 13, complete_time : 759, waiting_time : 723
# process : P18, arrival_time : 24, burst_time : 13, complete_time : 772, waiting_time : 735
# process : P100, arrival_time : 36, burst_time : 13, complete_time : 785, waiting_time : 736
# process : P78, arrival_time : 39, burst_time : 13, complete_time : 798, waiting_time : 746
# process : P7, arrival_time : 46, burst_time : 13, complete_time : 811, waiting_time : 752
# process : P27, arrival_time : 48, burst_time : 13, complete_time : 824, waiting_time : 763
# process : P38, arrival_time : 49, burst_time : 13, complete_time : 837, waiting_time : 775
# process : P42, arrival_time : 49, burst_time : 13, complete_time : 850, waiting_time : 788
# process : P11, arrival_time : 5, burst_time : 12, complete_time : 862, waiting_time : 845
# process : P50, arrival_time : 19, burst_time : 12, complete_time : 874, waiting_time : 843
# process : P13, arrival_time : 32, burst_time : 12, complete_time : 886, waiting_time : 842
# process : P62, arrival_time : 37, burst_time : 12, complete_time : 898, waiting_time : 849
# process : P6, arrival_time : 41, burst_time : 12, complete_time : 910, waiting_time : 857
# process : P55, arrival_time : 2, burst_time : 11, complete_time : 921, waiting_time : 908
# process : P87, arrival_time : 5, burst_time : 11, complete_time : 932, waiting_time : 916
# process : P30, arrival_time : 6, burst_time : 11, complete_time : 943, waiting_time : 926
# process : P3, arrival_time : 8, burst_time : 11, complete_time : 954, waiting_time : 935
# process : P69, arrival_time : 31, burst_time : 11, complete_time : 965, waiting_time : 923
# process : P15, arrival_time : 32, burst_time : 11, complete_time : 976, waiting_time : 933
# process : P26, arrival_time : 35, burst_time : 11, complete_time : 987, waiting_time : 941
# process : P36, arrival_time : 42, burst_time : 11, complete_time : 998, waiting_time : 945
# process : P58, arrival_time : 49, burst_time : 11, complete_time : 1009, waiting_time : 949
# process : P17, arrival_time : 7, burst_time : 10, complete_time : 1019, waiting_time : 1002
# process : P92, arrival_time : 8, burst_time : 10, complete_time : 1029, waiting_time : 1011
# process : P99, arrival_time : 16, burst_time : 10, complete_time : 1039, waiting_time : 1013
# process : P68, arrival_time : 26, burst_time : 10, complete_time : 1049, waiting_time : 1013
# process : P56, arrival_time : 32, burst_time : 10, complete_time : 1059, waiting_time : 1017
# process : P79, arrival_time : 36, burst_time : 10, complete_time : 1069, waiting_time : 1023
# process : P40, arrival_time : 1, burst_time : 9, complete_time : 1078, waiting_time : 1068
# process : P84, arrival_time : 6, burst_time : 9, complete_time : 1087, waiting_time : 1072
# process : P71, arrival_time : 8, burst_time : 9, complete_time : 1096, waiting_time : 1079
# process : P54, arrival_time : 10, burst_time : 9, complete_time : 1105, waiting_time : 1086
# process : P10, arrival_time : 13, burst_time : 9, complete_time : 1114, waiting_time : 1092
# process : P77, arrival_time : 24, burst_time : 9, complete_time : 1123, waiting_time : 1090
# process : P35, arrival_time : 44, burst_time : 9, complete_time : 1132, waiting_time : 1079
# process : P48, arrival_time : 7, burst_time : 8, complete_time : 1140, waiting_time : 1125
# process : P94, arrival_time : 26, burst_time : 8, complete_time : 1148, waiting_time : 1114
# process : P8, arrival_time : 3, burst_time : 7, complete_time : 1155, waiting_time : 1145
# process : P47, arrival_time : 9, burst_time : 7, complete_time : 1162, waiting_time : 1146
# process : P72, arrival_time : 9, burst_time : 7, complete_time : 1169, waiting_time : 1153
# process : P46, arrival_time : 31, burst_time : 7, complete_time : 1176, waiting_time : 1138
# process : P19, arrival_time : 36, burst_time : 7, complete_time : 1183, waiting_time : 1140
# process : P65, arrival_time : 43, burst_time : 7, complete_time : 1190, waiting_time : 1140
# process : P64, arrival_time : 46, burst_time : 7, complete_time : 1197, waiting_time : 1144
# process : P21, arrival_time : 4, burst_time : 6, complete_time : 1203, waiting_time : 1193
# process : P34, arrival_time : 8, burst_time : 6, complete_time : 1209, waiting_time : 1195
# process : P57, arrival_time : 15, burst_time : 6, complete_time : 1215, waiting_time : 1194
# process : P49, arrival_time : 17, burst_time : 6, complete_time : 1221, waiting_time : 1198
# process : P70, arrival_time : 20, burst_time : 6, complete_time : 1227, waiting_time : 1201
# process : P67, arrival_time : 46, burst_time : 6, complete_time : 1233, waiting_time : 1181
# process : P88, arrival_time : 5, burst_time : 5, complete_time : 1238, waiting_time : 1228
# process : P85, arrival_time : 10, burst_time : 5, complete_time : 1243, waiting_time : 1228
# process : P28, arrival_time : 13, burst_time : 5, complete_time : 1248, waiting_time : 1230
# process : P86, arrival_time : 21, burst_time : 5, complete_time : 1253, waiting_time : 1227
# process : P25, arrival_time : 39, burst_time : 5, complete_time : 1258, waiting_time : 1214
#
# Averages:
# Average Waiting Time: 723.74
# Average Turnaround Time: 736.32
# Results saved to LJF_Non_Preemptive_results.xlsx
#
# Algorithm Comparison:
#    average_waiting_time  average_turnaround_time           algorithm
# 0                585.00                   597.58                FCFS
# 1                477.61                   490.19  SJF_Non_Preemptive
# 2                476.13                   488.71      SJF_Preemptive
# 3                781.86                   799.65         Round_Robin
# 4                723.74                   736.32  LJF_Non_Preemptive
